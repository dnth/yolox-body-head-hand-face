# %%
import pandas as pd

# Load the large parquet file
df = pd.read_parquet('parquets/detection_results_train.parquet')
df
# Out:
#                                                    filename  classid  \
# 0         /workspace/yolo_v8_training/oiv7_full/train/00...        0
# 1         /workspace/yolo_v8_training/oiv7_full/train/00...        0
# 2         /workspace/yolo_v8_training/oiv7_full/train/00...        0
# 3         /workspace/yolo_v8_training/oiv7_full/train/00...        0
# 4         /workspace/yolo_v8_training/oiv7_full/train/00...        0
# ...                                                     ...      ...
# 10155324  /workspace/yolo_v8_training/oiv7_full/train/ff...        3
# 10155325  /workspace/yolo_v8_training/oiv7_full/train/ff...        3
# 10155326  /workspace/yolo_v8_training/oiv7_full/train/ff...        3
# 10155327  /workspace/yolo_v8_training/oiv7_full/train/ff...        3
# 10155328  /workspace/yolo_v8_training/oiv7_full/train/ff...        3
#
#              score   x1   y1   x2   y2
# 0         0.839814   39  719  292  990
# 1         0.813446   18  146  212  595
# 2         0.807047  257  695  424  945
# 3         0.773999  172  212  326  591
# 4         0.755840  664  196  896  490
# ...            ...  ...  ...  ...  ...
# 10155324  0.834842  704   86  808  198
# 10155325  0.789698  318   65  432  195
# 10155326  0.758495  225  100  293  155
# 10155327  0.707206  802  135  858  187
# 10155328  0.637762    0   78   40  149
#
# [10155329 rows x 7 columns]

# %%
# Define the chunk size
chunk_size = 1000000  # Adjust based on your needs

# Split and save chunks
for i, chunk in enumerate(range(0, df.shape[0], chunk_size)):
    df_subset = df.iloc[chunk:chunk + chunk_size]
    df_subset.to_parquet(f'parquets/detection_results_train_chunk_{i}.parquet')

# %%
df = pd.read_parquet("parquets/detection_results_train_chunk_0.parquet")

# %%
df
# Out:
#                                                  filename  classid     score  \
# 0       /workspace/yolo_v8_training/oiv7_full/train/00...        0  0.839814
# 1       /workspace/yolo_v8_training/oiv7_full/train/00...        0  0.813446
# 2       /workspace/yolo_v8_training/oiv7_full/train/00...        0  0.807047
# 3       /workspace/yolo_v8_training/oiv7_full/train/00...        0  0.773999
# 4       /workspace/yolo_v8_training/oiv7_full/train/00...        0  0.755840
# ...                                                   ...      ...       ...
# 999995  /workspace/yolo_v8_training/oiv7_full/train/14...        0  0.732610
# 999996  /workspace/yolo_v8_training/oiv7_full/train/14...        0  0.616251
# 999997  /workspace/yolo_v8_training/oiv7_full/train/14...        0  0.604764
# 999998  /workspace/yolo_v8_training/oiv7_full/train/14...        0  0.556185
# 999999  /workspace/yolo_v8_training/oiv7_full/train/14...        0  0.521048
#
#          x1   y1   x2   y2
# 0        39  719  292  990
# 1        18  146  212  595
# 2       257  695  424  945
# 3       172  212  326  591
# 4       664  196  896  490
# ...     ...  ...  ...  ...
# 999995  333  241  430  516
# 999996  352  211  416  295
# 999997  798  343  875  480
# 999998  726  247  813  480
# 999999  617  219  689  301
#
# [1000000 rows x 7 columns]
