# %%
import wandb

# %%
wandb.init(project="yolox-data-cleaning", entity="dnth")
# Out:
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: dnth. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.16.3
# Run data is saved locally in <code>/workspace/dnth/yolox-body-head-hand-face/notebooks/wandb/run-20240222_082047-21auzhby</code>
# Syncing run <strong><a href='https://wandb.ai/dnth/yolox-data-cleaning/runs/21auzhby' target="_blank">lunar-peony-3</a></strong> to <a href='https://wandb.ai/dnth/yolox-data-cleaning' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/dnth/yolox-data-cleaning' target="_blank">https://wandb.ai/dnth/yolox-data-cleaning</a>
#  View run at <a href='https://wandb.ai/dnth/yolox-data-cleaning/runs/21auzhby' target="_blank">https://wandb.ai/dnth/yolox-data-cleaning/runs/21auzhby</a>
# <button onClick="this.nextSibling.style.display='block';this.style.display='none';">Display W&B run</button><iframe src='https://wandb.ai/dnth/yolox-data-cleaning/runs/21auzhby?jupyter=true' style='border:none;width:100%;height:420px;display:none;'></iframe>

# %%
# Step 2: Create an artifact for your folder
# artifact.add_dir('path_to_your_folder')

artifact = wandb.Artifact('validation_set_oi7', type='detection_result')
artifact.add_file('../parquets/detection_results_validation.parquet')
wandb.log_artifact(artifact)

artifact = wandb.Artifact('train_set_oi7', type='detection_result')
artifact.add_file('../parquets/detection_results_train.parquet')
wandb.log_artifact(artifact)
# Out:
# <Artifact train_set_oi7>

# %%
# Finish your run
wandb.finish()
# Out:
# wandb: WARNING Source type is set to 'repo' but some required information is missing from the environment. A job will not be created from this run. See https://docs.wandb.ai/guides/launch/create-job
#  View run <strong style="color:#cdcd00">lunar-peony-3</strong> at: <a href='https://wandb.ai/dnth/yolox-data-cleaning/runs/21auzhby' target="_blank">https://wandb.ai/dnth/yolox-data-cleaning/runs/21auzhby</a><br/>Synced 5 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20240222_082047-21auzhby/logs</code>
